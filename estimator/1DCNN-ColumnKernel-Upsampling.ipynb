# %%
\subexec(open("inc_notebook.py").read())
# Out:
# current working dirF:\myProjects\tfKeras\UCSC\CMPS242\earthquake

# %%
import logging, sys, math,os
exec(open("estimator/initKeras.py").read())
# Out:
# Using TensorFlow backend.
# WARNING:root:Limiting GPU to 0.8. Increase it in initKeras.py. Next is available GPUs
# WARNING:root:['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")

if sys.modules.get( 'library.LivePlotKeras', False ) != False :
    del sys.modules['library.LivePlotKeras'] 
if sys.modules.get( 'LivePlotKeras', False ) != False :
    del sys.modules['LivePlotKeras'] 
from library.LivePlotKeras import *

logging.warning( "LivePlotKeras loaded" )

livePlotKeras = LivePlotKeras()
# Out:
# WARNING:root:LivePlotKeras loaded

# %%
if sys.modules.get( 'estimator.EstimatorIO', False ) != False :
    del sys.modules['estimator.EstimatorIO'] 
if sys.modules.get( 'EstimatorIO', False ) != False :
    del sys.modules['EstimatorIO'] 
from estimator.EstimatorIO import *

logging.warning( "EstimatorIO loaded" )

estimatorIO = EstimatorIO()
# Out:
# WARNING:root:EstimatorIO loaded

# %%
from embedding.MultipleBinEmbeddingType import *

if sys.modules.get( 'library.MultipleBinDataGenerator', False ) != False :
    del sys.modules['library.MultipleBinDataGenerator'] 
if sys.modules.get( 'MultipleBinDataGenerator', False ) != False :
    del sys.modules['MultipleBinDataGenerator'] 
from library.MultipleBinDataGenerator import *

logging.warning( "MultipleBinDataGenerator loaded" )

trainGenerator = MultipleBinDataGenerator(embedding=MultipleBinEmbeddingType.CNN_STATS, 
                                          batch_size=32, windowSize = 36, stride = 6)
# Out:
# WARNING:root:MultipleBinDataGenerator loaded
# D:\ProgramData\Anaconda3\envs\tf\lib\site-packages\sklearn\base.py:251: UserWarning: Trying to unpickle estimator RobustScaler from version 0.20.2 when using version 0.20.0. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# WARNING:root:shuffling: False

# %%
model_input = layers.Input( shape = ( 36, 275, 1 ) )
x = layers.Conv2D(8, 
        kernel_size = (20,1), 
        padding = 'same'
        )(model_input)

x = layers.LeakyReLU(alpha=0.1)(x)
x = layers.Dropout(0.1)(x)

x = layers.Conv2D(32, kernel_size=(10,1), activation=activations.tanh, padding='same')(x)
# x = layers.LeakyReLU(alpha=0.1)(x)
# x = layers.Dropout(0.2)(x)
x = layers.MaxPooling2D(pool_size=(4,1), padding='same')(x)
x = layers.UpSampling2D(size=(4,1))(x)

x = layers.Conv2D(16, kernel_size=(10,1), activation=activations.tanh, padding='same')(x)
# x = layers.LeakyReLU(alpha=0.1)(x)
# x = layers.Dropout(0.1)(x)
x = layers.MaxPooling2D(pool_size=(4,1), padding='same')(x)
x = layers.UpSampling2D(size=(4,1))(x)

x = layers.Conv2D(8, kernel_size=(3,1), activation=activations.relu, padding='same')(x)
x = layers.Dropout(0.1)(x)
x = layers.Flatten()(x)
x = layers.Dense(3)(x)
x = layers.Dense(1)(x)

model = models.Model(model_input, x, name = "1DCNN-ColumnKernel-Max-Pool-UpSampling2")
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 36, 275, 1)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 36, 275, 8)        168
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 36, 275, 8)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 36, 275, 8)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 36, 275, 32)       2592
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 275, 32)        0
# _________________________________________________________________
# up_sampling2d_15 (UpSampling (None, 36, 275, 32)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 36, 275, 16)       5136
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 9, 275, 16)        0
# _________________________________________________________________
# up_sampling2d_16 (UpSampling (None, 36, 275, 16)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 36, 275, 8)        392
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 36, 275, 8)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 79200)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 237603
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 4
# =================================================================
# Total params: 245,895
# Trainable params: 245,895
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=optimizers.Nadam(lr=0.001),
             loss = losses.MSE,
             metrics = [metrics.MSE, metrics.MAE])

# %%
history = model.fit_generator( generator=trainGenerator,
                    use_multiprocessing=False, 
                    workers=3, 
                    initial_epoch = 0,
                    epochs=20,
                    max_q_size = 100,
                    steps_per_epoch = trainGenerator.getNumberOfBatches(),
                    callbacks = [livePlotKeras]
                   )

# %%
estimatorIO.save(model, model.name)

# %%
if sys.modules.get( 'library.EmbeddingStatsGeneratorForTestPos', False ) != False :
    del sys.modules['library.EmbeddingStatsGeneratorForTestPos'] 
if sys.modules.get( 'EmbeddingStatsGeneratorForTestPos', False ) != False :
    del sys.modules['EmbeddingStatsGeneratorForTestPos'] 
from library.EmbeddingStatsGeneratorForTestPos import *  
logging.warning( "EmbeddingStatsGeneratorForTestPos loaded" )

embeddingType = 'cnn-stats-test'
generator = EmbeddingStatsGeneratorForTestPos(embeddingType = embeddingType)
# Out:
# WARNING:root:EmbeddingStatsGeneratorForTestPos loaded
# D:\ProgramData\Anaconda3\envs\tf\lib\site-packages\sklearn\base.py:251: UserWarning: Trying to unpickle estimator RobustScaler from version 0.20.2 when using version 0.20.0. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
import pandas as pd
output = pd.read_csv('F:/myProjects/cmps242/earthquake/data/sample_submission.csv')
dic = {}
for testName, batch in generator.batchesByFile():
    print(f'test: {testName}')
#     print(trainModel.predict(batch, batch_size=generator.numberOfEmbeddingPerFile))
    pred = model.predict(batch, batch_size=generator.numberOfEmbeddingPerFile)
    dic[testName] = pred
#     print( output.index[output['seg_id'] == testName])
    output.at[output.index[output['seg_id'] == testName], 'time_to_failure'] = np.median(pred)
# Out:
# test: seg_00030f
# test: seg_0012b5
# test: seg_00184e
# test: seg_003339
# test: seg_0042cc
# test: seg_004314
# test: seg_004cd2
# test: seg_004ee5
# test: seg_004f1f
# test: seg_00648a
# test: seg_006e4a
# test: seg_007a37
# test: seg_00a37e
# test: seg_00be11
# test: seg_00c35b
# test: seg_00cc91
# test: seg_00e5f7
# test: seg_00f3b9
# test: seg_010eab
# test: seg_0125d9
# test: seg_0144cb
# test: seg_0165c6
# test: seg_016913
# test: seg_016cdb
# test: seg_017314
# test: seg_01a8dc
# test: seg_01c775
# test: seg_01ecb0
# test: seg_02042f
# test: seg_025e78
# test: seg_032822
# test: seg_0339ca
# test: seg_037461
# test: seg_038879
# test: seg_03d386
# test: seg_03d63e
# test: seg_03d680
# test: seg_03f380
# test: seg_0445d7
# test: seg_046c28
# test: seg_0488a1
# test: seg_049957
# test: seg_04a696
# test: seg_04ae38
# test: seg_04b87a
# test: seg_04cceb
# test: seg_04ee93
# test: seg_04fd93
# test: seg_0536c9
# test: seg_055127
# test: seg_05a1b0
# test: seg_05a4ad
# test: seg_05b66a
# test: seg_05bef4
# test: seg_05e0d7
# test: seg_05f126
# test: seg_05f9d6
# test: seg_060ce4
# test: seg_061a33
# test: seg_0620e6
# test: seg_063865
# test: seg_065588
# test: seg_06893f
# test: seg_06b8c9
# test: seg_06bbc5
# test: seg_06d4a2
# test: seg_06d7ba
# test: seg_070bb0
# test: seg_071067
# test: seg_073696
# test: seg_075340
# test: seg_075f77
# test: seg_0775a7
# test: seg_077b7e
# test: seg_079e34
# test: seg_07c815
# test: seg_07cd72
# test: seg_07f37c
# test: seg_07f8df
# test: seg_07fc6d
# test: seg_086a61
# test: seg_0870ab
# test: seg_0879a8
# test: seg_08b136
# test: seg_08f441
# test: seg_08fd5b
# test: seg_091c9d
# test: seg_093a0a
# test: seg_0968f1
# test: seg_0981f3
# test: seg_09dd59
# test: seg_09ed4e
# test: seg_09f0ff
# test: seg_0a0fbb
# test: seg_0a1bd0
# test: seg_0a42ba
# test: seg_0a45a1
# test: seg_0a97c4
# test: seg_0aa0fb
# test: seg_0b07c7
# test: seg_0b082e
# test: seg_0b32f7
# test: seg_0b3b94
# test: seg_0b48c4
# test: seg_0b4b24
# test: seg_0b54ac
# test: seg_0b76f5
# test: seg_0b9ad8
# test: seg_0b9ba3
# test: seg_0ba210
# test: seg_0ba585
# test: seg_0bb5fd
# test: seg_0bc877
# test: seg_0be6ee
# test: seg_0c12cc
# test: seg_0c1d3a
# test: seg_0c247b
# test: seg_0c3943
# test: seg_0c4e31
# test: seg_0c74cf
# test: seg_0c8502
# test: seg_0c89ce
# test: seg_0c9aa8
# test: seg_0cb81b
# test: seg_0cca14
# test: seg_0cdcc8
# test: seg_0cf651
# test: seg_0d0250
# test: seg_0d04b9
# test: seg_0d13a7
# test: seg_0d434c
# test: seg_0d540e
# test: seg_0d663a
# test: seg_0d6d68
# test: seg_0d762e
# test: seg_0d833c
# test: seg_0dae4b
# test: seg_0dc38f
# test: seg_0dcc40
# test: seg_0df469
# test: seg_0df75c
# test: seg_0dfe8c
# test: seg_0e1370
# test: seg_0e1fbe
# test: seg_0e3739
# test: seg_0e3d44
# test: seg_0e3ed2
# test: seg_0e4833
# test: seg_0e7cc5
# test: seg_0e8b79
# test: seg_0e9987
# test: seg_0e9bb3
# test: seg_0eb333
# test: seg_0ebfd9
# test: seg_0f565c
# test: seg_0f74a3
# test: seg_0f8961
# test: seg_0fc67a
# test: seg_0fca83
# test: seg_0fd3ff
# test: seg_1010ad
# test: seg_103b32
# test: seg_105cd9
# test: seg_1084af
# test: seg_10a595
# test: seg_10c09d
# test: seg_10f3a6
# test: seg_112b81
# test: seg_1144bc
# test: seg_114b79
# test: seg_115617
# test: seg_115a92
# test: seg_11647f
# test: seg_117278
# test: seg_117ff4
# test: seg_11860f
# test: seg_1201e8
# test: seg_121446
# test: seg_121cba
# test: seg_122ba9
# test: seg_123dd4
# test: seg_12ac20
# test: seg_12b9ba
# test: seg_12ee6e
# test: seg_130e17
# test: seg_13468a
# test: seg_136285
# test: seg_136695
# test: seg_137f8a
# test: seg_138807
# test: seg_13c2f0
# test: seg_13e25f
# test: seg_140bc5
# test: seg_141f34
# test: seg_146926
# test: seg_148698
# test: seg_14ad27
# test: seg_14c054
# test: seg_14c371
# test: seg_14c435
# test: seg_14c89d
# test: seg_14c8ce
# test: seg_14d1d3
# test: seg_14f5f0
# test: seg_151368
# test: seg_151d92
# test: seg_153d6a
# test: seg_154361
# test: seg_1562cb
# test: seg_158691
# test: seg_158764
# test: seg_15adff
# test: seg_15bf25
# test: seg_15c9f9
# test: seg_161aeb
# test: seg_161f5f
# test: seg_162fc4
# test: seg_16566c
# test: seg_166f70
# test: seg_168d1c
# test: seg_16a270
# test: seg_16c3a7
# test: seg_17067e
# test: seg_170684
# test: seg_170a0c
# test: seg_176542
# test: seg_17799c
# test: seg_179d90
# test: seg_17adc0
# test: seg_17d1ff
# test: seg_17e596
# test: seg_180481
# test: seg_18096a
# test: seg_1815fe
# test: seg_1827c5
# test: seg_184222
# test: seg_185ad6
# test: seg_18d1d0
# test: seg_18d307
# test: seg_18f633
# test: seg_18f853
# test: seg_18fb65
# test: seg_193404
# test: seg_19515c
# test: seg_195eda
# test: seg_1969c8
# test: seg_19b08e
# test: seg_19b9dd
# test: seg_19e1ff
# test: seg_19ec5c
# test: seg_1a0e94
# test: seg_1a0eca
# test: seg_1a671a
# test: seg_1a791c
# test: seg_1a8e06
# test: seg_1a8f0d
# test: seg_1a8f2c
# test: seg_1abcaf
# test: seg_1ac9e2
# test: seg_1ae362
# test: seg_1afa29
# test: seg_1b08a4
# test: seg_1b1ad8
# test: seg_1b2298
# test: seg_1b78af
# test: seg_1baf33
# test: seg_1bd38e
# test: seg_1bf7b3
# test: seg_1c401b
# test: seg_1c4c5b
# test: seg_1c4e72
# test: seg_1c849d
# test: seg_1c904f
# test: seg_1c929e
# test: seg_1cb942
# test: seg_1cd352
# test: seg_1cf1b5
# test: seg_1d044c
# test: seg_1d11e5
# test: seg_1d596d
# test: seg_1d980f
# test: seg_1da819
# test: seg_1db443
# test: seg_1db8e8
# test: seg_1dec9c
# test: seg_1e0523
# test: seg_1e0b82
# test: seg_1e572b
# test: seg_1e617a
# test: seg_1e61d6
# test: seg_1e677e
# test: seg_1eae76
# test: seg_1ebe6b
# test: seg_1ece48
# test: seg_1eeb8f
# test: seg_1ef708
# test: seg_1f1e60
# test: seg_1f3d44
# test: seg_1f3ede
# test: seg_1f5240
# test: seg_1f7cf8
# test: seg_1f9aed
# test: seg_1fa983
# test: seg_1fc7ab
# test: seg_1fe311
# test: seg_2005a7
# test: seg_2018c8
# test: seg_204dc6
# test: seg_208ba5
# test: seg_2099f4
# test: seg_20a990
# test: seg_20b8d0
# test: seg_20cbac
# test: seg_20cc25
# test: seg_20d9de
# test: seg_20e9ad
# test: seg_210388
# test: seg_211299
# test: seg_211486
# test: seg_214492
# test: seg_217eed
# test: seg_218049
# test: seg_21eebb
# test: seg_21faa9
# test: seg_222c5f
# test: seg_225320
# test: seg_226e60
# test: seg_229eda
# test: seg_22e509
# test: seg_2313d1
# test: seg_232559
# test: seg_23323e
# test: seg_2367fb
# test: seg_238242
# test: seg_2383c2
# test: seg_2396a2
# test: seg_23b123
# test: seg_23bdf9
# test: seg_23c947
# test: seg_23efb0
# test: seg_23f823
# test: seg_23fe27
# test: seg_241266
# test: seg_24157a
# test: seg_24458d
# test: seg_2465ce
# test: seg_247262
# test: seg_24ba8d
# test: seg_24c078
# test: seg_24c1c9
# test: seg_24e071
# test: seg_24f338
# test: seg_257b8a
# test: seg_2597af
# test: seg_259c63
# test: seg_259d65
# test: seg_259dd3
# test: seg_25aa9f
# test: seg_25ab3f
# test: seg_25b38a
# test: seg_25c8dc
# test: seg_25cca7
# test: seg_25e76d
# test: seg_26049e
# test: seg_263deb
# test: seg_263fb3
# test: seg_2642d0
# test: seg_2642d4
# test: seg_264c7d
# test: seg_266805
# test: seg_266c6e
# test: seg_266d4e
# test: seg_268249
# test: seg_268625
# test: seg_268956
# test: seg_26a2a0
# test: seg_26cba3
# test: seg_26edaa
# test: seg_2700bd
# test: seg_272a47
# test: seg_274a1a
# test: seg_2774c4
# test: seg_279725
# test: seg_27a282
# test: seg_27b7c8
# test: seg_27db4d
# test: seg_27de37
# test: seg_27f532
# test: seg_27ff17
# test: seg_280863
# test: seg_280e3b
# test: seg_284223
# test: seg_284923
# test: seg_287e60
# test: seg_287fef
# test: seg_288001
# test: seg_2883ec
# test: seg_289d99
# test: seg_28fc32
# test: seg_29022f
# test: seg_2916e3
# test: seg_293dbf
# test: seg_293dc2
# test: seg_29475f
# test: seg_295b1c
# test: seg_2977cd
# test: seg_29a073
# test: seg_29acb7
# test: seg_29c772
# test: seg_29c906
# test: seg_29d497
# test: seg_29d4c6
# test: seg_29e799
# test: seg_2a0ace
# test: seg_2a0afc
# test: seg_2a0dc0
# test: seg_2a2f1e
# test: seg_2a4551
# test: seg_2a6343
# test: seg_2a8351
# test: seg_2aa101
# test: seg_2abd33
# test: seg_2b2cb3
# test: seg_2b372b
# test: seg_2b4959
# test: seg_2b6d52
# test: seg_2ba79a
# test: seg_2bcbde
# test: seg_2be983
# test: seg_2bf5be
# test: seg_2bf9dd
# test: seg_2c3203
# test: seg_2c5e9f
# test: seg_2c6011
# test: seg_2c69e4
# test: seg_2c762c
# test: seg_2cac57
# test: seg_2cadc0
# test: seg_2cdbe3
# test: seg_2d3828
# test: seg_2d402d
# test: seg_2d427f
# test: seg_2d5544
# test: seg_2d7cc4
# test: seg_2d92f0
# test: seg_2db7dc
# test: seg_2dc6ff
# test: seg_2dccec
# test: seg_2dcd3a
# test: seg_2dcd84
# test: seg_2dfb91
# test: seg_2e2372
# test: seg_2e50fb
# test: seg_2e64af
# test: seg_2e71dd
# test: seg_2e88dd
# test: seg_2e917f
# test: seg_2e9a47
# test: seg_2ea616
# test: seg_2eccb9
# test: seg_2ece02
# test: seg_2ed79b
# test: seg_2eddf6
# test: seg_2ee95c
# test: seg_2efd5c
# test: seg_2f1664
# test: seg_2f4f14
# test: seg_2f5695
# test: seg_2f60db
# test: seg_2f86cd
# test: seg_2f8e19
# test: seg_2f8f6d
# test: seg_2f9336
# test: seg_2f9581
# test: seg_2fb672
# test: seg_2fe382
# test: seg_301c1e
# test: seg_30207d
# test: seg_304581
# test: seg_304b87
# test: seg_304df5
# test: seg_30501b
# test: seg_3065ba
# test: seg_30661b
# test: seg_306756
# test: seg_30ad2a
# test: seg_30b043
# test: seg_30da11
# test: seg_30fd84
# test: seg_310230
# test: seg_31064b
# test: seg_311499
# test: seg_311b5e
# test: seg_3128e6
# test: seg_3151ff
# test: seg_31631c
# test: seg_316f86
# test: seg_318135
# test: seg_31a51f
# test: seg_31a6cd
# test: seg_31b808
# test: seg_31c0f4
# test: seg_31d763
# test: seg_31d7bf
# test: seg_31d810
# test: seg_31ddc5
# test: seg_3234ca
# test: seg_324447
# test: seg_324537
# test: seg_325790
# test: seg_326eb7
# test: seg_327ed4
# test: seg_32906d
# test: seg_32ad0f
# test: seg_32c904
# test: seg_32d747
# test: seg_32e763
# test: seg_32f3a9
# test: seg_32f6df
# test: seg_32f72d
# test: seg_32fc4e
# test: seg_330579
# test: seg_3319b5
# test: seg_331f2b
# test: seg_3340b9
# test: seg_335170
# test: seg_337b8c
# test: seg_339f80
# test: seg_33c30d
# test: seg_342ce6
# test: seg_343571
# test: seg_3452b2
# test: seg_34a2b8
# test: seg_34a8f7
# test: seg_34abd2
# test: seg_34ef79
# test: seg_3506d6
# test: seg_35269b
# test: seg_355717
# test: seg_355d19
# test: seg_35a2d7
# test: seg_35b009
# test: seg_35b753
# test: seg_35ba8f
# test: seg_35c587
# test: seg_35dd45
# test: seg_35ee83
# test: seg_36147d
# test: seg_361f5a
# test: seg_3631ec
# test: seg_3661de
# test: seg_369570
# test: seg_36b77f
# test: seg_36e32d
# test: seg_3706be
# test: seg_373a04
# test: seg_373ba6
# test: seg_37608b
# test: seg_3761d0
# test: seg_37669c
# test: seg_376908
# test: seg_377134
# test: seg_3788c5
# test: seg_37bf85
# test: seg_37f3fb
# test: seg_38001b
# test: seg_383b6b
# test: seg_383f2e
# test: seg_3865bc
# test: seg_3878d0
# test: seg_389906
# test: seg_38ad16
# test: seg_38ee24
# test: seg_392019
# test: seg_39300d
# test: seg_395e0e
# test: seg_397983
# test: seg_397dc9
# test: seg_398a25
# test: seg_39a886
# test: seg_39ad50
# test: seg_3a1600
# test: seg_3a22ac
# test: seg_3a80c5
# test: seg_3a8a76
# test: seg_3aca44
# test: seg_3adb1a
# test: seg_3ae4d9
# test: seg_3af649
# test: seg_3b2013
# test: seg_3b30fd
# test: seg_3b4414
# test: seg_3b7175
# test: seg_3b7724
# test: seg_3b95d2
# test: seg_3b95dc
# test: seg_3ba485
# test: seg_3bb90a
# test: seg_3bc9ed
# test: seg_3bd97e
# test: seg_3bf9ac
# test: seg_3bfcf6
# test: seg_3c3ddf
# test: seg_3c4106
# test: seg_3c64fb
# test: seg_3c8545
# test: seg_3cba49
# test: seg_3cbccf
# test: seg_3ce740
# test: seg_3cfb73
# test: seg_3d059a
# test: seg_3d06cc
# test: seg_3d19fc
# test: seg_3d1cb3
# test: seg_3d1f2e
# test: seg_3d581c
# test: seg_3d6aac
# test: seg_3d6e79
# test: seg_3d9aa0
# test: seg_3db0a8
# test: seg_3e00cd
# test: seg_3e55d5
# test: seg_3e87b4
# test: seg_3ec967
# test: seg_3edf51
# test: seg_3f2086
# test: seg_3f3689
# test: seg_3f3983
# test: seg_3f5be6
# test: seg_3f80ef
# test: seg_3f99c8
# test: seg_3fb24b
# test: seg_3fc7ca
# test: seg_3fdae0
# test: seg_407b2b
# test: seg_40b3aa
# test: seg_40f810
# test: seg_411225
# test: seg_414d0f
# test: seg_4185b3
# test: seg_419531
# test: seg_419b2a
# test: seg_41a267
# test: seg_41aadc
# test: seg_41ab7e
# test: seg_41be18
# test: seg_41be7d
# test: seg_41f45e
# test: seg_420bcc
# test: seg_420d4e
# test: seg_421a96
# test: seg_421da1
# test: seg_423ebe
# test: seg_425462
# test: seg_42648c
# test: seg_4280d9
# test: seg_428d66
# test: seg_42c4c9
# test: seg_42e7e8
# test: seg_42ff14
# test: seg_430e66
# test: seg_43383f
# test: seg_434c96
# test: seg_43597f
# test: seg_43c6f4
# test: seg_440106
# test: seg_4401d8
# test: seg_441c6d
# test: seg_4435bd
# test: seg_447972
# test: seg_447b8b
# test: seg_447cb3
# test: seg_44d3ca
# test: seg_455b16
# test: seg_456149
# test: seg_457234
# test: seg_45838b
# test: seg_4587bb
# test: seg_45a8a9
# test: seg_45b051
# test: seg_45e062
# test: seg_45e4ed
# test: seg_45e7ad
# test: seg_46012e
# test: seg_460436
# test: seg_461ab5
# test: seg_461b63
# test: seg_462c1d
# test: seg_464839
# test: seg_468bc9
# test: seg_468fdb
# test: seg_46a42b
# test: seg_46b84d
# test: seg_46c6d3
# test: seg_46dd7c
# test: seg_4729a7
# test: seg_4743ab
# test: seg_4743fa
# test: seg_476700
# test: seg_476bdb
# test: seg_477c83
# test: seg_478327
# test: seg_47a48f
# test: seg_47d374
# test: seg_47fed6
# test: seg_482745
# test: seg_4848e3
# test: seg_484901
# test: seg_486973
# test: seg_48a4b3
# test: seg_48a80c
# test: seg_48b545
# test: seg_48feba
# test: seg_490092
# test: seg_490d6e
# test: seg_492dc6
# test: seg_49322d
# test: seg_49336f
# test: seg_495573
# test: seg_496d07
# test: seg_496dad
# test: seg_49b0cb
# test: seg_49d84b
# test: seg_49fdf0
# test: seg_4a2525
# test: seg_4a6096
# test: seg_4a719c
# test: seg_4a91a9
# test: seg_4a9e6b
# test: seg_4a9e8d
# test: seg_4ab7bf
# test: seg_4abc29
# test: seg_4acc4b
# test: seg_4ad5a2
# test: seg_4ad674
# test: seg_4adeda
# test: seg_4ae37c
# test: seg_4ae712
# test: seg_4b0839
# test: seg_4b4c91
# test: seg_4b4ffb
# test: seg_4b8044
# test: seg_4b953a
# test: seg_4ba3d1
# test: seg_4c067a
# test: seg_4c12b2
# test: seg_4c18e2
# test: seg_4c3a2b
# test: seg_4c4995
# test: seg_4c65e6
# test: seg_4c8db6
# test: seg_4ca6de
# test: seg_4cb0d7
# test: seg_4cb9c6
# test: seg_4ce234
# test: seg_4d0008
# test: seg_4d0041
# test: seg_4d0c45
# test: seg_4d18f4
# test: seg_4d2671
# test: seg_4d53c2
# test: seg_4d5a4a
# test: seg_4d7c56
# test: seg_4d8f0f
# test: seg_4db886
# test: seg_4db997
# test: seg_4dbbd1
# test: seg_4ddddc
# test: seg_4dfa03
# test: seg_4e0c4a
# test: seg_4e2c66
# test: seg_4e3bd7
# test: seg_4e627b
# test: seg_4e9646
# test: seg_4ea3fa
# test: seg_4ea81c
# test: seg_4eb127
# test: seg_4eeaef
# test: seg_4eef28
# test: seg_4f48b4
# test: seg_4f5931
# test: seg_4f76a2
# test: seg_4f83a3
# test: seg_4fa87d
# test: seg_4fce5b
# test: seg_4fd191
# test: seg_500108
# test: seg_5009d9
# test: seg_500c80
# test: seg_502fab
# test: seg_507065
# test: seg_5090fa
# test: seg_509d55
# test: seg_50a667
# test: seg_50b048
# test: seg_50e270
# test: seg_511d25
# test: seg_512b3e
# test: seg_514543
# test: seg_5147e1
# test: seg_514b85
# test: seg_5165a4
# test: seg_517345
# test: seg_517425
# test: seg_51865e
# test: seg_518b1e
# test: seg_51b68c
# test: seg_51f0a2
# test: seg_51f6fd
# test: seg_521a88
# test: seg_523945
# test: seg_524b39
# test: seg_5254ce
# test: seg_5255c0
# test: seg_52636c
# test: seg_529be4
# test: seg_529c99
# test: seg_52c139
# test: seg_530a02
# test: seg_53103b
# test: seg_5311d1
# test: seg_533613
# test: seg_53498a
# test: seg_53a557
# test: seg_53a5fd
# test: seg_53bdf5
# test: seg_53caf1
# test: seg_53d818
# test: seg_53e645
# test: seg_53fa13
# test: seg_5407b0
# test: seg_5445bc
# test: seg_54490e
# test: seg_545fda
# test: seg_5467c8
# test: seg_546864
# test: seg_5470ca
# test: seg_5495ca
# test: seg_54af0d
# test: seg_54b0ee
# test: seg_54d0f3
# test: seg_55239a
# test: seg_552b8e
# test: seg_5559d9
# test: seg_555f63
# test: seg_5597ed
# test: seg_55a0c3
# test: seg_55a9a4
# test: seg_55b566
# test: seg_55d50b
# test: seg_561cf4
# test: seg_563059
# test: seg_5639b3
# test: seg_566efe
# test: seg_56e3e7
# test: seg_56e6f1
# test: seg_56ebc7
# test: seg_570a20
# test: seg_570d69
# test: seg_572172
# test: seg_5759c9
# test: seg_5765b6
# test: seg_578e84
# test: seg_57908c
# test: seg_57b6c0
# test: seg_57dd68
# test: seg_57ea44
# test: seg_580b65
# test: seg_581fac
# test: seg_585872
# test: seg_586726
# test: seg_586c0f
# test: seg_5887a8
# test: seg_588f61
# test: seg_58d52d
# test: seg_58e74b
# test: seg_58e9f9
# test: seg_58ea74
# test: seg_59058a
# test: seg_590fa5
# test: seg_591954
# test: seg_5924f5
# test: seg_592807
# test: seg_593c34
# test: seg_5965d8
# test: seg_596ae3
# test: seg_5975f4
# test: seg_597bd6
# test: seg_59818b
# test: seg_59cd7d
# test: seg_59cfdb
# test: seg_59d484
# test: seg_59de0b
# test: seg_59e1db
# test: seg_59eb97
# test: seg_5a0479
# test: seg_5a1adb
# test: seg_5a242e
# test: seg_5a67b5
# test: seg_5a947e
# test: seg_5abfdd
# test: seg_5ad847
# test: seg_5b392b
# test: seg_5b7325
# test: seg_5b8c39
# test: seg_5bc0b0
# test: seg_5bd9ae
# test: seg_5bdb47
# test: seg_5bfbf0
# test: seg_5c0929
# test: seg_5c1a4d
# test: seg_5c530f
# test: seg_5c57a8
# test: seg_5c8ae5
# test: seg_5c9077
# test: seg_5cd98b
# test: seg_5cde88
# test: seg_5cfba9
# test: seg_5cfdc4
# test: seg_5d333e
# test: seg_5d45db
# test: seg_5d92af
# test: seg_5d94b2
# test: seg_5e020f
# test: seg_5e0902
# test: seg_5e1bba
# test: seg_5e541f
# test: seg_5e635a
# test: seg_5e668a
# test: seg_5e70a7
# test: seg_5e7abf
# test: seg_5e8ef4
# test: seg_5eb380
# test: seg_5ec0e3
# test: seg_5ed47e
# test: seg_5ef47e
# test: seg_5f0a92
# test: seg_5f24d3
# test: seg_5f352e
# test: seg_5f355e
# test: seg_5f46a5
# test: seg_5f7fd9
# test: seg_5fe414
# test: seg_60277f
# test: seg_6074f9
# test: seg_607559
# test: seg_60ab20
# test: seg_60b696
# test: seg_60dacd
# test: seg_60df2a
# test: seg_610379
# test: seg_61219c
# test: seg_613702
# test: seg_614b50
# test: seg_6153ca
# test: seg_6167f0
# test: seg_616c8b
# test: seg_61b50d
# test: seg_61f504
# test: seg_620ee4
# test: seg_622e9d
# test: seg_62331a
# test: seg_6262c4
# test: seg_629822
# test: seg_62a403
# test: seg_62c582
# test: seg_63130f
# test: seg_633651
# test: seg_634180
# test: seg_634f05
# test: seg_635770
# test: seg_63582a
# test: seg_63c13d
# test: seg_63c518
# test: seg_63c8e4
# test: seg_63c983
# test: seg_63c9a3
# test: seg_63d651
# test: seg_6422d1
# test: seg_643d1f
# test: seg_643f86
# test: seg_64bcb9
# test: seg_64be5d
# test: seg_64be91
# test: seg_64daae
# test: seg_64dcf0
# test: seg_64f8dc
# test: seg_650de2
# test: seg_651808
# test: seg_652cc2
# test: seg_655780
# test: seg_655ad6
# test: seg_655cae
# test: seg_658bf4
# test: seg_659ff8
# test: seg_65b962
# test: seg_65c4e1
# test: seg_65ef95
# test: seg_65f01e
# test: seg_65fbac
# test: seg_660fe1
# test: seg_660fef
# test: seg_661629
# test: seg_666056
# test: seg_6681ee
# test: seg_66820a
# test: seg_6696d0
# test: seg_66b7c3
# test: seg_66e45a
# test: seg_66ed4d
# test: seg_670bde
# test: seg_67330f
# test: seg_673c60
# test: seg_67599b
# test: seg_679dd2
# test: seg_67aa76
# test: seg_68102c
# test: seg_683ddf
# test: seg_686edc
# test: seg_687a5c
# test: seg_68a484
# test: seg_68da94
# test: seg_691a72
# test: seg_692e7a
# test: seg_6951e0
# test: seg_695380
# test: seg_696621
# test: seg_6968c8
# test: seg_69787a
# test: seg_69a230
# test: seg_69a53e
# test: seg_69dbad
# test: seg_6a05e7
# test: seg_6a116b
# test: seg_6a26de
# test: seg_6a45a0
# test: seg_6a4ad1
# test: seg_6ab188
# test: seg_6ac67a
# test: seg_6ac82a
# test: seg_6ae32d
# test: seg_6b0107
# test: seg_6b2ce0
# test: seg_6b3a9d
# test: seg_6b4e04
# test: seg_6b536d
# test: seg_6b9511
# test: seg_6b9d02
# test: seg_6be48e
# test: seg_6c292b
# test: seg_6c309f
# test: seg_6c34c2
# test: seg_6c8a45
# test: seg_6c909f
# test: seg_6cfb76
# test: seg_6d01a3
# test: seg_6d35cd
# test: seg_6d36a1
# test: seg_6d4109
# test: seg_6d4fa6
# test: seg_6d6fad
# test: seg_6da1ff
# test: seg_6dac5d
# test: seg_6dd0fc
# test: seg_6de4fd
# test: seg_6de935
# test: seg_6df48e
# test: seg_6dfab7
# test: seg_6e12ae
# test: seg_6e12ee
# test: seg_6e1ee7
# test: seg_6e572a
# test: seg_6e5a38
# test: seg_6e7f73
# test: seg_6e98aa
# test: seg_6eb146
# test: seg_6ed49a
# test: seg_6edcb8
# test: seg_6eedcc
# test: seg_6f17de
# test: seg_6f2222
# test: seg_6f3d90
# test: seg_6f60b2
# test: seg_6f650f
# test: seg_6f9a98
# test: seg_6fb17f
# test: seg_6fc3ef
# test: seg_6fc8b3
# test: seg_6fd5bb
# test: seg_7012af
# test: seg_7020c5
# test: seg_702e03
# test: seg_703cea
# test: seg_705463
# test: seg_708349
# test: seg_70991d
# test: seg_709b6a
# test: seg_709d08
# test: seg_70a60e
# test: seg_70b375
# test: seg_70be4d
# test: seg_70e891
# test: seg_70edf5
# test: seg_70fb30
# test: seg_7120ac
# test: seg_71238c
# test: seg_71348a
# test: seg_715e2c
# test: seg_715ff6
# test: seg_7189ca
# test: seg_718b53
# test: seg_71936f
# test: seg_71b4e0
# test: seg_71b975
# test: seg_71c9e9
# test: seg_71f571
# test: seg_7211f1
# test: seg_724df9
# test: seg_725772
# test: seg_725e84
# test: seg_727fc7
# test: seg_72858d
# test: seg_72859b
# test: seg_72aba8
# test: seg_72b68c
# test: seg_72c307
# test: seg_72ebda
# test: seg_72f40a
# test: seg_730ebe
# test: seg_734a88
# test: seg_73565e
# test: seg_735cdd
# test: seg_73858d
# test: seg_738be6
# test: seg_739643
# test: seg_739679
# test: seg_739856
# test: seg_739fb0
# test: seg_73ab4a
# test: seg_73b0f7
# test: seg_740837
# test: seg_741fc1
# test: seg_74235f
# test: seg_7428e7
# test: seg_743775
# test: seg_74537f
# test: seg_746d1d
# test: seg_7480f4
# test: seg_74b264
# test: seg_74b3bd
# test: seg_74ce61
# test: seg_74d58a
# test: seg_74d8cc
# test: seg_74dda9
# test: seg_74f330
# test: seg_74fcfc
# test: seg_74ffde
# test: seg_750244
# test: seg_750c93
# test: seg_750d20
# test: seg_750e7e
# test: seg_75211e
# test: seg_753190
# test: seg_753ba6
# test: seg_7540f3
# test: seg_75438e
# test: seg_755d50
# test: seg_75654d
# test: seg_758374
# test: seg_758ca4
# test: seg_759fb1
# test: seg_75a878
# test: seg_75c34b
# test: seg_75cd6a
# test: seg_75dc3e
# test: seg_75e669
# test: seg_75e93c
# test: seg_75eb90
# test: seg_75ffc9
# test: seg_760d70
# test: seg_76106f
# test: seg_762188
# test: seg_762be4
# test: seg_7630c5
# test: seg_766e42
# test: seg_76b76f
# test: seg_76c2fa
# test: seg_76d16c
# test: seg_76e914
# test: seg_76f1af
# test: seg_76f3f2
# test: seg_76f76d
# test: seg_774ad2
# test: seg_77bf79
# test: seg_77c546
# test: seg_77db7b
# test: seg_77dbe7
# test: seg_77df38
# test: seg_77e7bf
# test: seg_77ea14
# test: seg_77f9e3
# test: seg_77fe77
# test: seg_7848f8
# test: seg_7862ed
# test: seg_786ff6
# test: seg_78852d
# test: seg_78addc
# test: seg_78d817
# test: seg_78db0a
# test: seg_78ded2
# test: seg_78fc4b
# test: seg_790108
# test: seg_7949da
# test: seg_79c47a
# test: seg_79dc90
# test: seg_79e301
# test: seg_7a09ec
# test: seg_7a521c
# test: seg_7a5243
# test: seg_7a9228
# test: seg_7a9f2b
# test: seg_7aeca4
# test: seg_7b0936
# test: seg_7b2994
# test: seg_7b3017
# test: seg_7b5f90
# test: seg_7bb771
# test: seg_7bec10
# test: seg_7bf143
# test: seg_7c0376
# test: seg_7c10c1
# test: seg_7c2beb
# test: seg_7c2c48
# test: seg_7c6c31
# test: seg_7c88d1
# test: seg_7c9433
# test: seg_7cb417
# test: seg_7cbb45
# test: seg_7cd6b1
# test: seg_7cdfe5
# test: seg_7ce9cb
# test: seg_7cef95
# test: seg_7d17eb
# test: seg_7d2535
# test: seg_7d2e57
# test: seg_7d65c7
# test: seg_7d718e
# test: seg_7d88e3
# test: seg_7d994f
# test: seg_7ddc30
# test: seg_7df3dd
# test: seg_7e3b3e
# test: seg_7e9eb7
# test: seg_7eb108
# test: seg_7ebdc3
# test: seg_7ed2dd
# test: seg_7ef97b
# test: seg_7efdd5
# test: seg_7f3ab0
# test: seg_7f5b6f
# test: seg_7f786b
# test: seg_7f93b2
# test: seg_7f9b3a
# test: seg_7fa6ec
# test: seg_7fac26
# test: seg_7fd3a3
# test: seg_7fd6b7
# test: seg_80211c
# test: seg_804fb5
# test: seg_80622d
# test: seg_807901
# test: seg_80b9b4
# test: seg_80fb86
# test: seg_812962
# test: seg_812a50
# test: seg_813aab
# test: seg_814b1f
# test: seg_816b7a
# test: seg_818382
# test: seg_81a8ea
# test: seg_81bebd
# test: seg_81c1a6
# test: seg_81c432
# test: seg_81f798
# test: seg_8200d2
# test: seg_82303e
# test: seg_82316b
# test: seg_8244bf
# test: seg_82456a
# test: seg_826208
# test: seg_827804
# test: seg_827a21
# test: seg_827c07
# test: seg_82c138
# test: seg_82ce27
# test: seg_82d7b6
# test: seg_830cff
# test: seg_8310ea
# test: seg_8324a4
# test: seg_8328f5
# test: seg_832a4d
# test: seg_8344ee
# test: seg_8353f5
# test: seg_836aac
# test: seg_836ef0
# test: seg_83bef8
# test: seg_83cb2c
# test: seg_83dc2e
# test: seg_83ef67
# test: seg_83f476
# test: seg_83f89e
# test: seg_83f928
# test: seg_8456d3
# test: seg_845a2a
# test: seg_8472f3
# test: seg_848695
# test: seg_84a65d
# test: seg_84b9d9
# test: seg_84c7fb
# test: seg_84fc12
# test: seg_8509db
# test: seg_850d95
# test: seg_8515fd
# test: seg_853302
# test: seg_854d91
# test: seg_857304
# test: seg_85762d
# test: seg_8599ec
# test: seg_85c1c0
# test: seg_85e90e
# test: seg_85e9c6
# test: seg_85fb0a
# test: seg_864fcf
# test: seg_8658b3
# test: seg_86720f
# test: seg_8681aa
# test: seg_86892f
# test: seg_868c85
# test: seg_86cfe9
# test: seg_86d847
# test: seg_86e874
# test: seg_87232d
# test: seg_876904
# test: seg_8773cf
# test: seg_8777bd
# test: seg_8785e2
# test: seg_878d2c
# test: seg_87a616
# test: seg_87a67a
# test: seg_87e4e8
# test: seg_87f6c8
# test: seg_8826f4
# test: seg_885f53
# test: seg_8866f0
# test: seg_88a81d
# test: seg_88b289
# test: seg_890181
# test: seg_89791c
# test: seg_89885a
# test: seg_899bf0
# test: seg_89b090
# test: seg_89d8a0
# test: seg_89e207
# test: seg_89eed6
# test: seg_89f975
# test: seg_8a3306
# test: seg_8a41bf
# test: seg_8a6b0e
# test: seg_8a7201
# test: seg_8a8220
# test: seg_8a8375
# test: seg_8ab3a7
# test: seg_8ae847
# test: seg_8aeb99
# test: seg_8b39c4
# test: seg_8b798b
# test: seg_8baeab
# test: seg_8bc20c
# test: seg_8bde47
# test: seg_8be2da
# test: seg_8be76c
# test: seg_8bec6f
# test: seg_8bf229
# test: seg_8c0114
# test: seg_8c1760
# test: seg_8c1cca
# test: seg_8c1e7d
# test: seg_8c341c
# test: seg_8c6d4e
# test: seg_8c6e34
# test: seg_8cd159
# test: seg_8cdf83
# test: seg_8ce632
# test: seg_8cf573
# test: seg_8d030a
# test: seg_8d135f
# test: seg_8d3a9d
# test: seg_8d4435
# test: seg_8d4965
# test: seg_8d5113
# test: seg_8d6578
# test: seg_8d6a7d
# test: seg_8da61a
# test: seg_8db6f0
# test: seg_8dcf3c
# test: seg_8dd2ab
# test: seg_8dd3ba
# test: seg_8dfc7e
# test: seg_8dfd7a
# test: seg_8e5704
# test: seg_8e6a3f
# test: seg_8e7194
# test: seg_8e7fca
# test: seg_8ebdea
# test: seg_8f1127
# test: seg_8f25b0
# test: seg_8f3247
# test: seg_8f3dfe
# test: seg_8f4654
# test: seg_8f4781
# test: seg_8f5589
# test: seg_8f592b
# test: seg_8f6284
# test: seg_8fb0d0
# test: seg_8fb29e
# test: seg_8fb828
# test: seg_8fc754
# test: seg_8fd465
# test: seg_902074
# test: seg_902bc1
# test: seg_903aba
# test: seg_907c52
# test: seg_90a0be
# test: seg_90b174
# test: seg_90bf60
# test: seg_90c258
# test: seg_90e904
# test: seg_90ec68
# test: seg_90ef18
# test: seg_911066
# test: seg_9122aa
# test: seg_913ffc
# test: seg_914a62
# test: seg_91596c
# test: seg_915b3e
# test: seg_91607c
# test: seg_919a6a
# test: seg_919c5c
# test: seg_91bf8c
# test: seg_91cff2
# test: seg_91eaeb
# test: seg_91f512
# test: seg_91f664
# test: seg_91fc29
# test: seg_920132
# test: seg_92092a
# test: seg_922914
# test: seg_922990
# test: seg_92310f
# test: seg_929ded
# test: seg_92a5f1
# test: seg_92af10
# test: seg_92b095
# test: seg_92bd37
# test: seg_92be9f
# test: seg_931244
# test: seg_93211c
# test: seg_932828
# test: seg_934087
# test: seg_939f5c
# test: seg_93d864
# test: seg_93f935
# test: seg_941759
# test: seg_943de0
# test: seg_944c98
# test: seg_945bc8
# test: seg_946d71
# test: seg_946d9a
# test: seg_947700
# test: seg_9485c0
# test: seg_94a133
# test: seg_94aa0a
# test: seg_94c48c
# test: seg_94d150
# test: seg_94d573
# test: seg_94ecad
# test: seg_950048
# test: seg_952faa
# test: seg_95357d
# test: seg_95644e
# test: seg_957ece
# test: seg_95b321
# test: seg_95f45e
# test: seg_961d02
# test: seg_961ddf
# test: seg_9626a4
# test: seg_96642e
# test: seg_966f3d
# test: seg_967ae4
# test: seg_96cd5d
# test: seg_96dab2
# test: seg_96db5e
# test: seg_96fa35
# test: seg_970b35
# test: seg_970e86
# test: seg_974049
# test: seg_9757ac
# test: seg_979a8f
# test: seg_97a161
# test: seg_97ad82
# test: seg_97d9ed
# test: seg_97e4a9
# test: seg_9802c3
# test: seg_9825e0
# test: seg_983778
# test: seg_986976
# test: seg_986b6e
# test: seg_9872f9
# test: seg_988e69
# test: seg_98a819
# test: seg_98be13
# test: seg_98c0b6
# test: seg_98c44d
# test: seg_98c544
# test: seg_98ebaa
# test: seg_98f624
# test: seg_9940e8
# test: seg_996c37
# test: seg_99ccbd
# test: seg_99f677
# test: seg_99f76c
# test: seg_9a1a4f
# test: seg_9a1c76
# test: seg_9a43ef
# test: seg_9a6025
# test: seg_9a74d8
# test: seg_9a7c46
# test: seg_9a7d1d
# test: seg_9a812d
# test: seg_9a81a3
# test: seg_9a8a1f
# test: seg_9a9041
# test: seg_9a92db
# test: seg_9aa6e2
# test: seg_9ab405
# test: seg_9ad261
# test: seg_9ad925
# test: seg_9ae1a1
# test: seg_9b0439
# test: seg_9b44d2
# test: seg_9b7ef8
# test: seg_9b7f93
# test: seg_9bab11
# test: seg_9bd388
# test: seg_9bee43
# test: seg_9c00d7
# test: seg_9c090f
# test: seg_9c2843
# test: seg_9c3d6a
# test: seg_9c3ef8
# test: seg_9c635d
# test: seg_9c6715
# test: seg_9c8162
# test: seg_9c8bc8
# test: seg_9ca72e
# test: seg_9caf50
# test: seg_9cb464
# test: seg_9d1b26
# test: seg_9d1dbe
# test: seg_9d2528
# test: seg_9d3013
# test: seg_9d452d
# test: seg_9d57a1
# test: seg_9d68cf
# test: seg_9d6ff0
# test: seg_9d7490
# test: seg_9d79d4
# test: seg_9dcae1
# test: seg_9ddc99
# test: seg_9dea8d
# test: seg_9df32d
# test: seg_9e25e9
# test: seg_9e3837
# test: seg_9e61da
# test: seg_9e7dff
# test: seg_9e8323
# test: seg_9e8ca4
# test: seg_9e962b
# test: seg_9ee0aa
# test: seg_9f042e
# test: seg_9f12c6
# test: seg_9f22a0
# test: seg_9f4fd4
# test: seg_9f57c4
# test: seg_9f6315
# test: seg_9f7542
# test: seg_9fc7c2
# test: seg_9fd9b8
# test: seg_9fe8b9
# test: seg_a00985
# test: seg_a009e6
# test: seg_a03e6a
# test: seg_a05c22
# test: seg_a06228
# test: seg_a0646a
# test: seg_a0979e
# test: seg_a0a423
# test: seg_a11dd5
# test: seg_a12acb
# test: seg_a133bc
# test: seg_a14212
# test: seg_a16a1b
# test: seg_a173d8
# test: seg_a18246
# test: seg_a1a511
# test: seg_a1acb2
# test: seg_a1b3cc
# test: seg_a1d8da
# test: seg_a1e5b0
# test: seg_a1edc1
# test: seg_a247ac
# test: seg_a25c46
# test: seg_a2986f
# test: seg_a2c108
# test: seg_a2d47d
# test: seg_a2e2c8
# test: seg_a2fd8b
# test: seg_a31d6e
# test: seg_a31fe3
# test: seg_a35c82
# test: seg_a35e7c
# test: seg_a39ebc
# test: seg_a39f3b
# test: seg_a39fa8
# test: seg_a3ab46
# test: seg_a3d4d6
# test: seg_a41c2c
# test: seg_a4208a
# test: seg_a420d4
# test: seg_a436bc
# test: seg_a437cb
# test: seg_a45455
# test: seg_a47cce
# test: seg_a489e1
# test: seg_a49ccc
# test: seg_a4ad7c
# test: seg_a4e745
# test: seg_a50d28
# test: seg_a5271e
# test: seg_a53e4c
# test: seg_a543e5
# test: seg_a55540
# test: seg_a55a17
# test: seg_a56c04
# test: seg_a58a6e
# test: seg_a5934a
# test: seg_a5d37f
# test: seg_a5dea6
# test: seg_a5f4dd
# test: seg_a5fbcc
# test: seg_a61e1c
# test: seg_a63573
# test: seg_a674d2
# test: seg_a68007
# test: seg_a68ffb
# test: seg_a69246
# test: seg_a6959c
# test: seg_a6bf91
# test: seg_a6c5cc
# test: seg_a6cd86
# test: seg_a6e801
# test: seg_a6e99c
# test: seg_a6eed3
# test: seg_a704ee
# test: seg_a7561c
# test: seg_a7b454
# test: seg_a7d0eb
# test: seg_a7e49b
# test: seg_a80123
# test: seg_a802fa
# test: seg_a80f6f
# test: seg_a82229
# test: seg_a84c13
# test: seg_a86231
# test: seg_a8685e
# test: seg_a86a05
# test: seg_a87e79
# test: seg_a88097
# test: seg_a88dde
# test: seg_a8bb2f
# test: seg_a8ddf7
# test: seg_a8e6df
# test: seg_a8e71a
# test: seg_a9089b
# test: seg_a91c03
# test: seg_a93a88
# test: seg_a96b47
# test: seg_a975df
# test: seg_a99161
# test: seg_a99799
# test: seg_a99be9
# test: seg_a9a820
# test: seg_a9b957
# test: seg_a9f80e
# test: seg_aa0180
# test: seg_aa1adf
# test: seg_aa508a
# test: seg_aa78e0
# test: seg_aa7a4b
# test: seg_aa98cc
# test: seg_aa9b8e
# test: seg_aaa2ae
# test: seg_aabc52
# test: seg_aae025
# test: seg_ab001b
# test: seg_ab15ad
# test: seg_ab2a78
# test: seg_ab3f14
# test: seg_ab4bca
# test: seg_ab644e
# test: seg_ab70bd
# test: seg_ab9654
# test: seg_aba501
# test: seg_abaad2
# test: seg_abb03a
# test: seg_abb06a
# test: seg_abc5fd
# test: seg_abda04
# test: seg_abeca6
# test: seg_ac45ae
# test: seg_ac5c61
# test: seg_ac68bb
# test: seg_ac9de5
# test: seg_acd715
# test: seg_acf2f4
# test: seg_ad3a44
# test: seg_ad3cf0
# test: seg_ad591c
# test: seg_ad759c
# test: seg_ad82ca
# test: seg_ad949a
# test: seg_ada42c
# test: seg_ada81a
# test: seg_ade769
# test: seg_adf94a
# test: seg_adf986
# test: seg_ae32a6
# test: seg_ae3388
# test: seg_ae3d92
# test: seg_ae42b3
# test: seg_ae9626
# test: seg_ae9761
# test: seg_aec276
# test: seg_aed434
# test: seg_aee7c0
# test: seg_aee9bf
# test: seg_aeeb31
# test: seg_af1650
# test: seg_af2472
# test: seg_af6204
# test: seg_af703b
# test: seg_af959f
# test: seg_afa4a1
# test: seg_afadfb
# test: seg_afca81
# test: seg_afd665
# test: seg_b00f05
# test: seg_b02e31
# test: seg_b03de5
# test: seg_b08e9d
# test: seg_b0a794
# test: seg_b0bf65
# test: seg_b0cf32
# test: seg_b0d251
# test: seg_b0f9cd
# test: seg_b108c9
# test: seg_b13220
# test: seg_b13fb9
# test: seg_b197e2
# test: seg_b1a35c
# test: seg_b1b95e
# test: seg_b1fea8
# test: seg_b20487
# test: seg_b21273
# test: seg_b23489
# test: seg_b253ee
# test: seg_b25dde
# test: seg_b26368
# test: seg_b284b2
# test: seg_b291c0
# test: seg_b2b29d
# test: seg_b2b331
# test: seg_b2e045
# test: seg_b31961
# test: seg_b32d1d
# test: seg_b35174
# test: seg_b36650
# test: seg_b36c8a
# test: seg_b378bc
# test: seg_b3883e
# test: seg_b3cf21
# test: seg_b3d886
# test: seg_b402ac
# test: seg_b41d3c
# test: seg_b42170
# test: seg_b4402d
# test: seg_b44c2e
# test: seg_b47c19
# test: seg_b4c040
# test: seg_b4cb44
# test: seg_b4f7a8
# test: seg_b50239
# test: seg_b51380
# test: seg_b51b7c
# test: seg_b52710
# test: seg_b52add
# test: seg_b52dac
# test: seg_b54024
# test: seg_b568c6
# test: seg_b57e76
# test: seg_b5804a
# test: seg_b58542
# test: seg_b5a447
# test: seg_b5aee9
# test: seg_b6254c
# test: seg_b63de1
# test: seg_b64c9c
# test: seg_b66b87
# test: seg_b686e5
# test: seg_b687fc
# test: seg_b691c5
# test: seg_b69455
# test: seg_b695b3
# test: seg_b6bdaa
# test: seg_b6c10d
# test: seg_b6cb2b
# test: seg_b72413
# test: seg_b735a5
# test: seg_b77bf5
# test: seg_b782c7
# test: seg_b78883
# test: seg_b7a8a1
# test: seg_b7b098
# test: seg_b7da0a
# test: seg_b7eeb6
# test: seg_b80358
# test: seg_b80366
# test: seg_b80b89
# test: seg_b8141c
# test: seg_b853c1
# test: seg_b853f8
# test: seg_b86ce1
# test: seg_b8725b
# test: seg_b8745c
# test: seg_b87cf5
# test: seg_b88baa
# test: seg_b89218
# test: seg_b89e47
# test: seg_b8b72f
# test: seg_b8bb87
# test: seg_b8fd73
# test: seg_b91011
# test: seg_b917b5
# test: seg_b91ae2
# test: seg_b9361a
# test: seg_b9365c
# test: seg_b947ae
# test: seg_b95010
# test: seg_b95a77
# test: seg_b9619c
# test: seg_b9ad7f
# test: seg_b9bdd7
# test: seg_b9d8a0
# test: seg_b9de03
# test: seg_b9ec4b
# test: seg_ba0485
# test: seg_ba1d68
# test: seg_ba2c48
# test: seg_ba3c47
# test: seg_ba3e74
# test: seg_ba4ea3
# test: seg_ba5e7e
# test: seg_ba83da
# test: seg_ba941e
# test: seg_ba98dc
# test: seg_ba9dbf
# test: seg_baa745
# test: seg_bb171f
# test: seg_bb180c
# test: seg_bb2d77
# test: seg_bb5e15
# test: seg_bb6904
# test: seg_bb6fcb
# test: seg_bb92b1
# test: seg_bbb01e
# test: seg_bbbc30
# test: seg_bbf805
# test: seg_bbfd4e
# test: seg_bc07c8
# test: seg_bc1d67
# test: seg_bc2186
# test: seg_bc437b
# test: seg_bca500
# test: seg_bcc8f1
# test: seg_bce23c
# test: seg_bce305
# test: seg_bcf2d9
# test: seg_bcf6af
# test: seg_bcfad6
# test: seg_bd00c4
# test: seg_bd2b0c
# test: seg_bd31bf
# test: seg_bd40f2
# test: seg_bd4d30
# test: seg_bd5022
# test: seg_bd629b
# test: seg_bd6f5f
# test: seg_bd7109
# test: seg_bdae02
# test: seg_bdf84b
# test: seg_be0cdc
# test: seg_be0dfa
# test: seg_be19e2
# test: seg_be30ce
# test: seg_be4612
# test: seg_be62ef
# test: seg_be65f2
# test: seg_be811d
# test: seg_beb650
# test: seg_beda44
# test: seg_bee792
# test: seg_bf1294
# test: seg_bf1430
# test: seg_bf1a72
# test: seg_bf2d1f
# test: seg_bf4bf2
# test: seg_bf4ec0
# test: seg_bf58ce
# test: seg_bf7224
# test: seg_bfdd14
# test: seg_bfe0b6
# test: seg_bff05e
# test: seg_bff392
# test: seg_c01a57
# test: seg_c01d9a
# test: seg_c01f63
# test: seg_c0260d
# test: seg_c047b7
# test: seg_c05a7d
# test: seg_c07b7c
# test: seg_c08d36
# test: seg_c09a41
# test: seg_c0c0ed
# test: seg_c0d7da
# test: seg_c0e1b9
# test: seg_c0ea9f
# test: seg_c106ca
# test: seg_c10a58
# test: seg_c11828
# test: seg_c11a4f
# test: seg_c12d7d
# test: seg_c146a8
# test: seg_c15d21
# test: seg_c17817
# test: seg_c179f8
# test: seg_c183e4
# test: seg_c186dc
# test: seg_c18d5a
# test: seg_c1fe9a
# test: seg_c20a27
# test: seg_c20c06
# test: seg_c21723
# test: seg_c21d60
# test: seg_c22bd4
# test: seg_c23429
# test: seg_c23641
# test: seg_c243a6
# test: seg_c24946
# test: seg_c25855
# test: seg_c267a5
# test: seg_c26fb4
# test: seg_c27591
# test: seg_c2a0c8
# test: seg_c2b8f7
# test: seg_c3507f
# test: seg_c35940
# test: seg_c365de
# test: seg_c3836b
# test: seg_c3f672
# test: seg_c3f8d7
# test: seg_c41d1d
# test: seg_c42490
# test: seg_c42952
# test: seg_c44bbc
# test: seg_c46ce6
# test: seg_c472cf
# test: seg_c47bdc
# test: seg_c4af54
# test: seg_c5064e
# test: seg_c509ff
# test: seg_c522f8
# test: seg_c5256d
# test: seg_c52ae6
# test: seg_c5325c
# test: seg_c550b1
# test: seg_c565bd
# test: seg_c571ef
# test: seg_c588c1
# test: seg_c58ca5
# test: seg_c5abaa
# test: seg_c5c455
# test: seg_c5c6ea
# test: seg_c5dada
# test: seg_c5dee4
# test: seg_c5f986
# test: seg_c5fc3b
# test: seg_c5fc87
# test: seg_c607eb
# test: seg_c60dca
# test: seg_c60f1d
# test: seg_c627fc
# test: seg_c62a06
# test: seg_c65135
# test: seg_c654e7
# test: seg_c666dd
# test: seg_c671f7
# test: seg_c6b514
# test: seg_c6c29f
# test: seg_c6f0a2
# test: seg_c6f533
# test: seg_c6f9c2
# test: seg_c703be
# test: seg_c70fde
# test: seg_c714d0
# test: seg_c73df6
# test: seg_c747ad
# test: seg_c747b4
# test: seg_c7a3bc
# test: seg_c7a401
# test: seg_c7a579
# test: seg_c7b424
# test: seg_c80857
# test: seg_c81e10
# test: seg_c81fec
# test: seg_c8459f
# test: seg_c87c24
# test: seg_c901c0
# test: seg_c90be5
# test: seg_c9201c
# test: seg_c9481f
# test: seg_c94941
# test: seg_c9831a
# test: seg_c9e533
# test: seg_c9f80a
# test: seg_ca2d1b
# test: seg_ca407b
# test: seg_ca44a8
# test: seg_ca67ee
# test: seg_ca6d70
# test: seg_ca8389
# test: seg_ca88e3
# test: seg_ca9e39
# test: seg_caa919
# test: seg_cacd0a
# test: seg_cacd58
# test: seg_cb0e21
# test: seg_cb806c
# test: seg_cbcce9
# test: seg_cbfb19
# test: seg_cc096e
# test: seg_cc2c46
# test: seg_cc2e9b
# test: seg_cc4199
# test: seg_cc4932
# test: seg_cc4950
# test: seg_cc667b
# test: seg_cc7a19
# test: seg_cc7e39
# test: seg_ccdc28
# test: seg_cd0691
# test: seg_cd2b34
# test: seg_cd2b53
# test: seg_cd352f
# test: seg_cd43b4
# test: seg_cd699e
# test: seg_cd9f9b
# test: seg_cdadb5
# test: seg_cdf88e
# test: seg_ce00bb
# test: seg_ce46ba
# test: seg_ce472b
# test: seg_ce5520
# test: seg_ce5832
# test: seg_ce72e2
# test: seg_ce7537
# test: seg_ce9f59
# test: seg_cea185
# test: seg_ceab44
# test: seg_ceb942
# test: seg_cec2f2
# test: seg_cecd29
# test: seg_ced992
# test: seg_cedf3e
# test: seg_cee7d0
# test: seg_cf0e43
# test: seg_cf1371
# test: seg_cf25d2
# test: seg_cf3825
# test: seg_cf5764
# test: seg_cf646e
# test: seg_cf74e8
# test: seg_cf9a49
# test: seg_cfed24
# test: seg_cff594
# test: seg_d014a3
# test: seg_d0598e
# test: seg_d062a6
# test: seg_d07c62
# test: seg_d07ce8
# test: seg_d098df
# test: seg_d0c280
# test: seg_d0c8e2
# test: seg_d0f262
# test: seg_d0f803
# test: seg_d1045e
# test: seg_d11ca8
# test: seg_d14524
# test: seg_d146a6
# test: seg_d16534
# test: seg_d19980
# test: seg_d1a281
# test: seg_d1a2b9
# test: seg_d1a8b3
# test: seg_d1abaa
# test: seg_d1b91e
# test: seg_d1ca05
# test: seg_d1cb37
# test: seg_d1eee8
# test: seg_d1fbb8
# test: seg_d21066
# test: seg_d21eb6
# test: seg_d24095
# test: seg_d247da
# test: seg_d2551a
# test: seg_d26f7d
# test: seg_d27193
# test: seg_d27812
# test: seg_d29a4b
# test: seg_d2a533
# test: seg_d2ad9a
# test: seg_d2cb02
# test: seg_d2db6b
# test: seg_d2f588
# test: seg_d30a9d
# test: seg_d31583
# test: seg_d320f5
# test: seg_d328bb
# test: seg_d32f71
# test: seg_d32f8a
# test: seg_d35274
# test: seg_d356ab
# test: seg_d35e50
# test: seg_d36055
# test: seg_d36342
# test: seg_d36681
# test: seg_d36737
# test: seg_d37b05
# test: seg_d39131
# test: seg_d398df
# test: seg_d3992e
# test: seg_d3bb14
# test: seg_d3d8fc
# test: seg_d3f6b0
# test: seg_d3f967
# test: seg_d40bb2
# test: seg_d41daa
# test: seg_d42c77
# test: seg_d44589
# test: seg_d47aba
# test: seg_d4c763
# test: seg_d4dec8
# test: seg_d4ea17
# test: seg_d508db
# test: seg_d516e3
# test: seg_d56ae2
# test: seg_d56d32
# test: seg_d59e4e
# test: seg_d5b100
# test: seg_d5d3a1
# test: seg_d5dbc1
# test: seg_d5df41
# test: seg_d5f344
# test: seg_d60d18
# test: seg_d62e9c
# test: seg_d63175
# test: seg_d661ce
# test: seg_d668c0
# test: seg_d68930
# test: seg_d693b0
# test: seg_d6b198
# test: seg_d6b386
# test: seg_d6b546
# test: seg_d6dad6
# test: seg_d6ea73
# test: seg_d702b2
# test: seg_d71352
# test: seg_d740b2
# test: seg_d753f8
# test: seg_d78093
# test: seg_d78e7d
# test: seg_d795ab
# test: seg_d7967e
# test: seg_d7a805
# test: seg_d7ab50
# test: seg_d7f015
# test: seg_d7f53a
# test: seg_d8014d
# test: seg_d83890
# test: seg_d85e2e
# test: seg_d86eb6
# test: seg_d88da7
# test: seg_d89369
# test: seg_d90c5f
# test: seg_d91492
# test: seg_d9190c
# test: seg_d9352b
# test: seg_d962cc
# test: seg_d9750c
# test: seg_d9a2bb
# test: seg_d9b162
# test: seg_d9bb68
# test: seg_d9ce67
# test: seg_d9d0e4
# test: seg_d9dab4
# test: seg_da21ee
# test: seg_da7c3b
# test: seg_da80c4
# test: seg_da8b88
# test: seg_dab0f9
# test: seg_dad4f2
# test: seg_db3446
# test: seg_db3a95
# test: seg_db3fbe
# test: seg_db4185
# test: seg_db606c
# test: seg_db694a
# test: seg_db6d5f
# test: seg_db90c0
# test: seg_dbbb44
# test: seg_dbc615
# test: seg_dbf3f2
# test: seg_dc188b
# test: seg_dc1cf0
# test: seg_dc23c0
# test: seg_dc4698
# test: seg_dc5e63
# test: seg_dc6e94
# test: seg_dc73b8
# test: seg_dc7e0d
# test: seg_dca2c2
# test: seg_dcb51d
# test: seg_dcbe02
# test: seg_dcd9df
# test: seg_dcee28
# test: seg_dceeca
# test: seg_dcf242
# test: seg_dcfb4b
# test: seg_dd0b11
# test: seg_dd4594
# test: seg_dd699c
# test: seg_dd780d
# test: seg_dd8805
# test: seg_ddbadc
# test: seg_ddc800
# test: seg_ddd206
# test: seg_ddddf0
# test: seg_de225c
# test: seg_de3237
# test: seg_de3d5e
# test: seg_de4e1d
# test: seg_de8180
# test: seg_de98fa
# test: seg_de9e32
# test: seg_df0df7
# test: seg_df352f
# test: seg_df45b0
# test: seg_df8385
# test: seg_df8e0a
# test: seg_df99d4
# test: seg_dff078
# test: seg_e00465
# test: seg_e051bc
# test: seg_e05de2
# test: seg_e067ab
# test: seg_e09301
# test: seg_e0c329
# test: seg_e0ce38
# test: seg_e0cfd4
# test: seg_e0f296
# test: seg_e10d3b
# test: seg_e13bd8
# test: seg_e14149
# test: seg_e1468f
# test: seg_e15cb9
# test: seg_e197b8
# test: seg_e1a9e0
# test: seg_e1daa0
# test: seg_e1f045
# test: seg_e1f081
# test: seg_e20d76
# test: seg_e217fc
# test: seg_e2209b
# test: seg_e24496
# test: seg_e24f69
# test: seg_e256bd
# test: seg_e25aca
# test: seg_e266f4
# test: seg_e27c0a
# test: seg_e29670
# test: seg_e2b8b1
# test: seg_e2c82c
# test: seg_e3005e
# test: seg_e30e44
# test: seg_e30ef5
# test: seg_e34052
# test: seg_e37b8e
# test: seg_e3b1f1
# test: seg_e3ca24
# test: seg_e3cf1a
# test: seg_e3d751
# test: seg_e3dafa
# test: seg_e3e762
# test: seg_e40348
# test: seg_e405fe
# test: seg_e40d64
# test: seg_e41fc9
# test: seg_e47d2b
# test: seg_e481c7
# test: seg_e48c23
# test: seg_e49750
# test: seg_e4c15a
# test: seg_e4f203
# test: seg_e4f403
# test: seg_e50f16
# test: seg_e52f8c
# test: seg_e53a52
# test: seg_e54932
# test: seg_e5750a
# test: seg_e59dca
# test: seg_e5b510
# test: seg_e5c033
# test: seg_e5deec
# test: seg_e5e238
# test: seg_e5f9ec
# test: seg_e5fbc1
# test: seg_e60719
# test: seg_e6307f
# test: seg_e64dfa
# test: seg_e65e69
# test: seg_e66697
# test: seg_e6b236
# test: seg_e6bd3f
# test: seg_e6c973
# test: seg_e6e1df
# test: seg_e6e24e
# test: seg_e71dda
# test: seg_e72f10
# test: seg_e742dc
# test: seg_e76e6e
# test: seg_e7ac12
# test: seg_e7ced6
# test: seg_e7d1f8
# test: seg_e7d3e7
# test: seg_e80726
# test: seg_e81b50
# test: seg_e8385f
# test: seg_e85f55
# test: seg_e86e44
# test: seg_e86ed1
# test: seg_e86f77
# test: seg_e877a5
# test: seg_e8a2c4
# test: seg_e8a4f4
# test: seg_e8ac98
# test: seg_e8ad6b
# test: seg_e8b2b3
# test: seg_e8bcde
# test: seg_e8ce6a
# test: seg_e8d02f
# test: seg_e90c0d
# test: seg_e92526
# test: seg_e9272e
# test: seg_e96140
# test: seg_e98217
# test: seg_e9a09f
# test: seg_e9aa44
# test: seg_e9df42
# test: seg_e9e65b
# test: seg_ea0091
# test: seg_ea05c1
# test: seg_ea096b
# test: seg_ea098b
# test: seg_ea4d3a
# test: seg_ea78c0
# test: seg_ea8270
# test: seg_ea9d37
# test: seg_ea9fa4
# test: seg_eaa0ec
# test: seg_eabb2c
# test: seg_eacccf
# test: seg_ead30e
# test: seg_eb0b19
# test: seg_eb1d6e
# test: seg_eb2e11
# test: seg_eb32bc
# test: seg_eb47a9
# test: seg_eb692c
# test: seg_eb7595
# test: seg_eb7f91
# test: seg_eba22d
# test: seg_ebb79f
# test: seg_ebd77b
# test: seg_ebe36c
# test: seg_ebec3e
# test: seg_ec0e7b
# test: seg_ec4645
# test: seg_ec73d5
# test: seg_ec973c
# test: seg_eca2eb
# test: seg_ecaef0
# test: seg_eccb17
# test: seg_ecdca4
# test: seg_ecf28d
# test: seg_ecf81b
# test: seg_ed07b0
# test: seg_ed3e4c
# test: seg_ed52ac
# test: seg_ed7741
# test: seg_ed7dee
# test: seg_ed7f69
# test: seg_edda79
# test: seg_edecaa
# test: seg_ee1cfc
# test: seg_ee2781
# test: seg_ee4479
# test: seg_ee4ae5
# test: seg_ee7224
# test: seg_ee87e2
# test: seg_ee8f87
# test: seg_eea20e
# test: seg_eebbc2
# test: seg_eee89d
# test: seg_eefd4a
# test: seg_ef24bd
# test: seg_ef27c8
# test: seg_ef47c4
# test: seg_ef644a
# test: seg_ef660a
# test: seg_ef74dc
# test: seg_ef779d
# test: seg_ef9105
# test: seg_efb639
# test: seg_efbf3e
# test: seg_efc5fb
# test: seg_efd9ec
# test: seg_f003ca
# test: seg_f01368
# test: seg_f0181d
# test: seg_f02d32
# test: seg_f056d8
# test: seg_f0574b
# test: seg_f073e2
# test: seg_f0ce4a
# test: seg_f0cedb
# test: seg_f0d278
# test: seg_f0db55
# test: seg_f11620
# test: seg_f11f77
# test: seg_f165f6
# test: seg_f19f8e
# test: seg_f1a771
# test: seg_f1b916
# test: seg_f1f5b9
# test: seg_f21a22
# test: seg_f21bf4
# test: seg_f22163
# test: seg_f229bf
# test: seg_f24292
# test: seg_f2750c
# test: seg_f2a20d
# test: seg_f2ae5e
# test: seg_f2b0c5
# test: seg_f2cb5e
# test: seg_f2f5a3
# test: seg_f3063a
# test: seg_f30b2f
# test: seg_f30f0c
# test: seg_f322b1
# test: seg_f342a3
# test: seg_f34877
# test: seg_f383fb
# test: seg_f3c578
# test: seg_f43730
# test: seg_f43ab6
# test: seg_f455bc
# test: seg_f46cc1
# test: seg_f48363
# test: seg_f48db9
# test: seg_f4ad4b
# test: seg_f4d644
# test: seg_f52cdc
# test: seg_f5406b
# test: seg_f579ba
# test: seg_f57ca1
# test: seg_f59974
# test: seg_f5a4ee
# test: seg_f5a6ab
# test: seg_f5d2dd
# test: seg_f5e682
# test: seg_f60872
# test: seg_f618a8
# test: seg_f61b0e
# test: seg_f639cd
# test: seg_f639ec
# test: seg_f650cc
# test: seg_f6659e
# test: seg_f66db1
# test: seg_f679c6
# test: seg_f67ce2
# test: seg_f6828d
# test: seg_f69c38
# test: seg_f6a217
# test: seg_f6abc5
# test: seg_f6b70c
# test: seg_f6bae8
# test: seg_f6c0cb
# test: seg_f6c928
# test: seg_f6cfd4
# test: seg_f6d51b
# test: seg_f6e1ca
# test: seg_f6e89f
# test: seg_f6f523
# test: seg_f6f683
# test: seg_f7050a
# test: seg_f70b66
# test: seg_f71db8
# test: seg_f7290f
# test: seg_f734c8
# test: seg_f741af
# test: seg_f77ee5
# test: seg_f7d792
# test: seg_f7de40
# test: seg_f80e44
# test: seg_f83d28
# test: seg_f865be
# test: seg_f86c41
# test: seg_f88d4a
# test: seg_f8db0a
# test: seg_f8dd7e
# test: seg_f931de
# test: seg_f93ce5
# test: seg_f95fd3
# test: seg_f96d0e
# test: seg_f96d5a
# test: seg_f97274
# test: seg_f99b64
# test: seg_f9e4f2
# test: seg_f9eea3
# test: seg_fa0ac7
# test: seg_fa34c7
# test: seg_fa488e
# test: seg_fa4df0
# test: seg_fa6383
# test: seg_fa796b
# test: seg_fa9f00
# test: seg_fad815
# test: seg_fb00b3
# test: seg_fb11ba
# test: seg_fb1f5c
# test: seg_fb4c26
# test: seg_fb74f0
# test: seg_fb76ca
# test: seg_fb8af5
# test: seg_fb9491
# test: seg_fb9b2e
# test: seg_fbce13
# test: seg_fbd66b
# test: seg_fbddb9
# test: seg_fbe3c2
# test: seg_fbf17a
# test: seg_fbff25
# test: seg_fc407c
# test: seg_fc57d4
# test: seg_fc8fd6
# test: seg_fcb7d0
# test: seg_fcca66
# test: seg_fcd32e
# test: seg_fd19b8
# test: seg_fd374e
# test: seg_fd6340
# test: seg_fd8add
# test: seg_fd9ac1
# test: seg_fdba93
# test: seg_fdc1d4
# test: seg_fdd50e
# test: seg_fde767
# test: seg_fde86d
# test: seg_fdff11
# test: seg_fe2aac
# test: seg_fe5945
# test: seg_fe70c0
# test: seg_fe73b1
# test: seg_fe86f5
# test: seg_fea3e2
# test: seg_feb312
# test: seg_fedbd1
# test: seg_ff0f1b
# test: seg_ff1a62
# test: seg_ff2f2d
# WARNING:root:encountered exception while reading embedding #34113: [Errno 2] No such file or directory: 'C:/earthquake/cnn-stats-test-embedding/em_34113.dill'. Sliently progressing
# test: seg_ff4236
# test: seg_ff7478
# test: seg_ff79d9
# test: seg_ffbd6a
# test: seg_ffe7cc

# %%
output.to_csv(f'F:/myProjects/cmps242/earthquake/data/{model.name}.csv', index=False)
